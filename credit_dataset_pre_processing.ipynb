# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
risk_df = pd.read_csv('credit_risk_dataset.csv')

# %%
risk_df.shape
# Out:
# (32581, 12)

# %%
risk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
risk_df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# 50%        10.990000      0.000000             0.150000
# 75%        13.470000      0.000000             0.230000
# max        23.220000      1.000000             0.830000
#
#        cb_person_cred_hist_length
# count                32581.000000
# mean                     5.804211
# std                      4.055001
# min                      2.000000
# 25%                      3.000000
# 50%                      4.000000
# 75%                      8.000000
# max                     30.000000

# %%
risk_df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
risk_df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
sns.heatmap(risk_df.isnull())
# Out:
# <Axes: >

# %%
plt.title("Null values Distribution")
# Out:
# Text(0.5, 1.0, 'Null values Distribution')

# %%
risk_df["person_age"].unique()
# Out:
# array([ 22,  21,  25,  23,  24,  26, 144, 123,  20,  32,  34,  29,  33,
#         28,  35,  31,  27,  30,  36,  40,  50,  45,  37,  39,  44,  43,
#         41,  46,  38,  47,  42,  48,  49,  58,  65,  51,  53,  66,  61,
#         54,  57,  59,  62,  60,  55,  52,  64,  70,  78,  69,  56,  73,
#         63,  94,  80,  84,  76,  67])

# %%
risk_df['person_home_ownership'] = risk_df['person_home_ownership'].str.upper()
risk_df['person_home_ownership'].unique()
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER'], dtype=object)

# %%
risk_df['loan_intent'] = risk_df['loan_intent'].str.upper()
risk_df["loan_intent"].unique()
# Out:
# array(['PERSONAL', 'EDUCATION', 'MEDICAL', 'VENTURE', 'HOMEIMPROVEMENT',
#        'DEBTCONSOLIDATION'], dtype=object)

# %%
risk_df['loan_grade'] = risk_df['loan_grade'].str.upper()
risk_df["loan_grade"].unique()
# Out:
# array(['D', 'B', 'C', 'A', 'E', 'F', 'G'], dtype=object)

# %%
risk_df["loan_status"].unique()
# Out:
# array([1, 0])

# %%
risk_df['cb_person_default_on_file'] = risk_df['cb_person_default_on_file'].str.upper()
risk_df["cb_person_default_on_file"].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
risk_df["cb_person_cred_hist_length"].unique()
# Out:
# array([ 3,  2,  4,  8,  7,  6,  9, 10,  5, 11, 16, 15, 12, 13, 17, 14, 25,
#        28, 27, 22, 19, 29, 23, 26, 20, 21, 30, 24, 18])

# %%
risk_df['person_income'] = risk_df['person_income'].astype('float')

# %%
risk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  float64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 3.0+ MB

# %%
risk_df['person_emp_length'].mean()
# Out:
# 4.789686296787225

# %%
risk_df['person_emp_length'].median()
# Out:
# 4.0

# %%
risk_df['person_emp_length'].fillna(risk_df['person_emp_length'].median(), inplace=True)
risk_df.info()
risk_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  float64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           32581 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 3.0+ MB
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length                0
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
risk_df['person_emp_length'].unique()
# Out:
# array([123.,   5.,   1.,   4.,   8.,   2.,   6.,   7.,   0.,   9.,   3.,
#         10.,  11.,  18.,  12.,  17.,  14.,  16.,  13.,  19.,  15.,  20.,
#         22.,  21.,  24.,  23.,  26.,  25.,  27.,  28.,  31.,  41.,  34.,
#         29.,  38.,  30.])

# %%
risk_df['loan_int_rate'].unique()
# Out:
# array([16.02, 11.14, 12.87, 15.23, 14.27,  7.14, 12.42, 11.11,  8.9 ,
#        14.74, 10.37,  8.63,  7.9 , 18.39, 10.65, 20.25, 18.25, 10.99,
#         7.49, 16.77, 17.58,  7.29, 14.54, 12.68, 17.74,  9.32,  9.99,
#        12.84, 11.12,  6.62, 14.17, 13.85, 13.49,  7.51, 16.89,   nan,
#        17.99, 12.69,  7.88, 19.41, 10.38, 15.33, 16.45, 18.62, 15.96,
#        11.48,  5.99, 11.58, 15.7 , 15.99, 14.84, 14.42,  6.99, 13.61,
#         9.91, 13.48, 12.98, 13.57, 15.68, 13.06, 15.62, 11.71,  8.88,
#        12.18, 13.99,  5.42, 12.73, 11.49, 19.91, 11.83, 14.59,  9.64,
#        16.35, 18.67, 10.08, 10.36, 12.23, 16.07, 14.22, 14.79, 13.22,
#        11.86, 13.43, 15.28, 17.93,  9.25, 10.62, 18.43, 11.36, 15.65,
#        13.04, 17.04, 14.83, 14.65, 16.82, 10.25, 14.96, 11.99,  8.49,
#         6.17, 16.32, 14.35, 15.21, 14.09, 17.49, 13.92, 16.49,  5.79,
#        13.11,  6.54, 12.53, 15.95, 10.74, 15.27, 14.72, 13.35,  7.68,
#        14.46, 13.47,  6.03, 12.92, 18.64, 16.7 , 18.3 ,  9.63, 14.7 ,
#        15.37, 14.26,  8.  , 11.26, 19.04, 13.98, 15.58, 15.31,  9.33,
#        11.91,  8.38, 10.59, 16.  , 11.54, 12.61, 17.27, 15.05, 10.75,
#         6.39, 18.09, 19.74,  6.91, 14.93, 17.14, 11.03,  8.94, 11.46,
#         7.66, 17.56, 10.39, 16.29, 17.8 , 19.69, 15.83, 20.03, 20.16,
#        13.79, 11.89, 14.5 , 11.34,  9.62,  9.96, 18.99, 14.11, 17.19,
#         7.4 , 17.51, 14.61, 21.21, 14.91, 17.26, 10.71, 10.  , 16.95,
#        11.97, 12.99, 13.16,  9.76, 11.22, 16.69, 12.21,  7.74, 11.78,
#        11.66, 19.79,  9.88, 13.87, 17.39, 12.29, 10.83, 15.2 , 14.82,
#        14.88, 13.36,  6.76, 13.23,  9.45, 10.96, 13.72, 12.36, 11.41,
#        14.3 , 10.91, 16.63,  6.92, 10.95,  8.7 , 12.67, 12.41, 20.11,
#        14.18, 12.8 , 13.24, 12.09, 17.15, 19.47,  7.91, 10.46,  7.37,
#        11.28,  8.59, 19.03, 15.57,  8.32, 10.14, 19.29, 11.63, 12.72,
#        13.8 ,  7.12, 13.3 , 16.59, 21.27,  8.07,  9.67, 11.72, 12.22,
#        13.75,  9.38, 10.2 , 16.4 , 10.33, 12.54, 21.74,  7.43,  9.07,
#         6.  ,  9.7 , 10.01,  7.05, 10.28, 20.3 , 13.67,  7.42, 19.42,
#        21.36, 12.17,  9.83, 18.79, 14.38,  7.75, 14.75, 10.51, 13.12,
#        17.88,  9.2 , 11.59, 17.43, 13.93, 15.76, 18.21, 13.55, 15.13,
#         9.01, 16.08, 16.11, 14.12, 12.86, 19.39, 13.17, 15.45, 22.11,
#        12.62, 19.13, 12.49, 16.2 , 18.84, 16.33, 19.82, 20.89, 10.78,
#        15.88, 19.16, 20.62, 20.2 ,  9.51, 14.67, 12.12, 12.04, 15.07,
#        17.06, 13.62, 20.48, 18.53, 17.9 , 11.09, 13.84, 18.78, 15.01,
#        18.07, 17.03, 21.14, 17.46, 20.99, 21.64, 18.36, 20.17, 18.17,
#        22.06, 17.54, 17.44, 18.49, 20.86, 20.52, 15.25, 18.72, 20.9 ,
#        16.96, 15.38, 17.34, 14.62, 14.25, 14.07, 10.64, 22.48, 19.66,
#        23.22, 20.4 , 16.71, 18.54, 20.69, 16.15, 20.53])

# %%
risk_df['loan_int_rate'].mean()
# Out:
# 11.011694892245036

# %%
risk_df['loan_int_rate'].median()
# Out:
# 10.99

# %%
risk_df['loan_int_rate'].fillna(risk_df['loan_int_rate'].mean(), inplace=True)
risk_df.info()
risk_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  float64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           32581 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               32581 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 3.0+ MB
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
risk_df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       32581.000000  32581.000000
# mean      27.734600   6.607485e+04           4.767994   9589.371106
# std        6.348078   6.198312e+04           4.087372   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   32581.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.081605      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         8.490000      0.000000             0.090000
# 50%        11.011695      0.000000             0.150000
# 75%        13.110000      0.000000             0.230000
# max        23.220000      1.000000             0.830000
#
#        cb_person_cred_hist_length
# count                32581.000000
# mean                     5.804211
# std                      4.055001
# min                      2.000000
# 25%                      3.000000
# 50%                      4.000000
# 75%                      8.000000
# max                     30.000000

# %%
import seaborn as sns
figure = risk_df.boxplot(column='person_age')
plt.show()

# %%
risk_df[risk_df['person_age'] > 90.0]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 81            144       250000.0                  RENT                4.0
# 183           144       200000.0              MORTGAGE                4.0
# 575           123        80004.0                  RENT                2.0
# 747           123        78000.0                  RENT                7.0
# 32297         144      6000000.0              MORTGAGE               12.0
# 32416          94        24000.0                  RENT                1.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 81        VENTURE          C       4800      13.570000            0
# 183     EDUCATION          B       6000      11.860000            0
# 575     EDUCATION          B      20400      10.250000            0
# 747       VENTURE          B      20000      11.011695            0
# 32297    PERSONAL          C       5000      12.730000            0
# 32416     MEDICAL          C       6500      11.011695            0
#
#        loan_percent_income cb_person_default_on_file  \
# 81                    0.02                         N
# 183                   0.03                         N
# 575                   0.25                         N
# 747                   0.26                         N
# 32297                 0.00                         N
# 32416                 0.27                         N
#
#        cb_person_cred_hist_length
# 81                              3
# 183                             2
# 575                             3
# 747                             4
# 32297                          25
# 32416                          27

# %%
risk_df[risk_df['person_age'] > 80.0]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 81            144       250000.0                  RENT                4.0
# 183           144       200000.0              MORTGAGE                4.0
# 575           123        80004.0                  RENT                2.0
# 747           123        78000.0                  RENT                7.0
# 32297         144      6000000.0              MORTGAGE               12.0
# 32416          94        24000.0                  RENT                1.0
# 32506          84        94800.0              MORTGAGE                2.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 81        VENTURE          C       4800      13.570000            0
# 183     EDUCATION          B       6000      11.860000            0
# 575     EDUCATION          B      20400      10.250000            0
# 747       VENTURE          B      20000      11.011695            0
# 32297    PERSONAL          C       5000      12.730000            0
# 32416     MEDICAL          C       6500      11.011695            0
# 32506    PERSONAL          A      10000       7.510000            0
#
#        loan_percent_income cb_person_default_on_file  \
# 81                    0.02                         N
# 183                   0.03                         N
# 575                   0.25                         N
# 747                   0.26                         N
# 32297                 0.00                         N
# 32416                 0.27                         N
# 32506                 0.11                         N
#
#        cb_person_cred_hist_length
# 81                              3
# 183                             2
# 575                             3
# 747                             4
# 32297                          25
# 32416                          27
# 32506                          24

# %%
risk_df['person_age'].max()
# Out:
# 144

# %%
risk_df['person_age'].min()
# Out:
# 20

# %%
risk_df = risk_df.drop(risk_df[risk_df['person_age'] > 80.0].index, axis=0)
risk_df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22        59000.0                  RENT              123.0
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57        53000.0              MORTGAGE                1.0
# 32577          54       120000.0              MORTGAGE                4.0
# 32578          65        76000.0                  RENT                3.0
# 32579          56       150000.0              MORTGAGE                5.0
# 32580          66        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0             PERSONAL          D      35000          16.02            1
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 32576                          30
# 32577                          19
# 32578                          28
# 32579                          26
# 32580                          30
#
# [32574 rows x 12 columns]

# %%
risk_df[risk_df['person_age'] > 80.0]
# Out:
# Empty DataFrame
# Columns: [person_age, person_income, person_home_ownership, person_emp_length, loan_intent, loan_grade, loan_amnt, loan_int_rate, loan_status, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length]
# Index: []

# %%
figure = risk_df.boxplot(column='person_age')
plt.show()

# %%
figure = risk_df.boxplot(column='person_income')
plt.show()

# %%
figure = risk_df.boxplot(column='person_emp_length')
plt.show()

# %%
risk_df[risk_df['person_emp_length'] > 40.0]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22        59000.0                  RENT              123.0
# 210            21       192000.0              MORTGAGE              123.0
# 32355          78        48000.0                  RENT               41.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0        PERSONAL          D      35000          16.02            1
# 210       VENTURE          A      20000           6.54            0
# 32355     MEDICAL          A       3000           7.51            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 210                   0.10                         N
# 32355                 0.06                         N
#
#        cb_person_cred_hist_length
# 0                               3
# 210                             4
# 32355                          25

# %%
risk_df = risk_df.drop(risk_df[risk_df['person_emp_length'] > 40.0].index, axis=0)

# %%
risk_df[risk_df['person_emp_length'] > 40.0]
# Out:
# Empty DataFrame
# Columns: [person_age, person_income, person_home_ownership, person_emp_length, loan_intent, loan_grade, loan_amnt, loan_int_rate, loan_status, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length]
# Index: []

# %%
figure = risk_df.boxplot(column='person_emp_length')
plt.show()

# %%
figure = risk_df.boxplot(column='loan_int_rate')
plt.show()

# %%
risk_df[risk_df['loan_int_rate'] > 30.0]
# Out:
# Empty DataFrame
# Columns: [person_age, person_income, person_home_ownership, person_emp_length, loan_intent, loan_grade, loan_amnt, loan_int_rate, loan_status, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length]
# Index: []

# %%
figure = risk_df.boxplot(column='cb_person_cred_hist_length')
plt.show()

# %%
risk_df['age_range'] = pd.cut(risk_df['person_age'],
                           bins=[20, 31, 41, 51, 61, 71, 81],
                           labels=['20-30', '31-40', '41-50', '51-60', '61-70', '71-80'])
risk_df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# 5              21         9900.0                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32576          57        53000.0              MORTGAGE                1.0
# 32577          54       120000.0              MORTGAGE                4.0
# 32578          65        76000.0                  RENT                3.0
# 32579          56       150000.0              MORTGAGE                5.0
# 32580          66        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# 5              VENTURE          A       2500           7.14            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# 5                     0.25                         N
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length age_range
# 1                               2     20-30
# 2                               3     20-30
# 3                               2     20-30
# 4                               4     20-30
# 5                               2     20-30
# ...                           ...       ...
# 32576                          30     51-60
# 32577                          19     51-60
# 32578                          28     61-70
# 32579                          26     51-60
# 32580                          30     61-70
#
# [32571 rows x 13 columns]

# %%
risk_df[risk_df['person_income'] > 150000]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15             23       500000.0              MORTGAGE                7.0
# 20             25       162500.0                  RENT                2.0
# 33             25       306000.0                  RENT                2.0
# 34             26       300000.0              MORTGAGE               10.0
# 42             26       300000.0              MORTGAGE               10.0
# ...           ...            ...                   ...                ...
# 32543          52       720000.0              MORTGAGE                1.0
# 32544          58       780000.0              MORTGAGE                7.0
# 32546          60      1900000.0              MORTGAGE                5.0
# 32551          58       780000.0              MORTGAGE                7.0
# 32562          61       160000.0              MORTGAGE               30.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 15     DEBTCONSOLIDATION          B      30000      10.650000            0
# 20               VENTURE          A      35000       7.490000            0
# 33     DEBTCONSOLIDATION          C      24250      13.850000            0
# 34               MEDICAL          C       7800      13.490000            0
# 42               VENTURE          A      20000       7.880000            0
# ...                  ...        ...        ...            ...          ...
# 32543           PERSONAL          A       7925       8.940000            0
# 32544           PERSONAL          A       4500       6.910000            0
# 32546           PERSONAL          A       1500      11.011695            0
# 32551           PERSONAL          A       4500       6.910000            0
# 32562           PERSONAL          B      24000      10.380000            0
#
#        loan_percent_income cb_person_default_on_file  \
# 15                    0.06                         N
# 20                    0.22                         N
# 33                    0.08                         N
# 34                    0.03                         N
# 42                    0.07                         N
# ...                    ...                       ...
# 32543                 0.01                         N
# 32544                 0.01                         N
# 32546                 0.00                         N
# 32551                 0.01                         N
# 32562                 0.15                         N
#
#        cb_person_cred_hist_length age_range
# 15                              3     20-30
# 20                              4     20-30
# 33                              3     20-30
# 34                              4     20-30
# 42                              4     20-30
# ...                           ...       ...
# 32543                          30     51-60
# 32544                          20     51-60
# 32546                          21     51-60
# 32551                          19     51-60
# 32562                          21     51-60
#
# [1133 rows x 13 columns]

# %%
risk_df['person_income'].max()
# Out:
# 2039784.0

# %%
risk_df['income_range'] = pd.cut(risk_df['person_income'],
                              bins=[0, 30000, 50000, 75000, 100000, 150000, float('inf')],
                              labels=['0-30k', '30k-50k', '50k-75k', '75k-100k', '100k-150k', '>150k'])
risk_df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# 5              21         9900.0                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32576          57        53000.0              MORTGAGE                1.0
# 32577          54       120000.0              MORTGAGE                4.0
# 32578          65        76000.0                  RENT                3.0
# 32579          56       150000.0              MORTGAGE                5.0
# 32580          66        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# 5              VENTURE          A       2500           7.14            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# 5                     0.25                         N
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length age_range income_range
# 1                               2     20-30        0-30k
# 2                               3     20-30        0-30k
# 3                               2     20-30      50k-75k
# 4                               4     20-30      50k-75k
# 5                               2     20-30        0-30k
# ...                           ...       ...          ...
# 32576                          30     51-60      50k-75k
# 32577                          19     51-60    100k-150k
# 32578                          28     61-70     75k-100k
# 32579                          26     51-60    100k-150k
# 32580                          30     61-70      30k-50k
#
# [32571 rows x 14 columns]

# %%
risk_df['loan_amnt'].max()
# Out:
# 35000

# %%
figure = risk_df.boxplot(column='loan_amnt')
plt.show()

# %%
risk_df['loan_amount_range'] = pd.cut(risk_df['loan_amnt'],
                                   bins=[0, 5000, 10000, 15000, 20000, 25000, 30000, float('inf')],
                                   labels=['0-5k', '5k-10k', '10k-15k', '15k-20k', '20k-25k', '25k-30k', '>30k'])
risk_df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# 5              21         9900.0                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32576          57        53000.0              MORTGAGE                1.0
# 32577          54       120000.0              MORTGAGE                4.0
# 32578          65        76000.0                  RENT                3.0
# 32579          56       150000.0              MORTGAGE                5.0
# 32580          66        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# 5              VENTURE          A       2500           7.14            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# 5                     0.25                         N
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length age_range income_range loan_amount_range
# 1                               2     20-30        0-30k              0-5k
# 2                               3     20-30        0-30k            5k-10k
# 3                               2     20-30      50k-75k              >30k
# 4                               4     20-30      50k-75k              >30k
# 5                               2     20-30        0-30k              0-5k
# ...                           ...       ...          ...               ...
# 32576                          30     51-60      50k-75k            5k-10k
# 32577                          19     51-60    100k-150k           15k-20k
# 32578                          28     61-70     75k-100k              >30k
# 32579                          26     51-60    100k-150k           10k-15k
# 32580                          30     61-70      30k-50k            5k-10k
#
# [32571 rows x 15 columns]

# %%
risk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32571 entries, 1 to 32580
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32571 non-null  int64
#  1   person_income               32571 non-null  float64
#  2   person_home_ownership       32571 non-null  object
#  3   person_emp_length           32571 non-null  float64
#  4   loan_intent                 32571 non-null  object
#  5   loan_grade                  32571 non-null  object
#  6   loan_amnt                   32571 non-null  int64
#  7   loan_int_rate               32571 non-null  float64
#  8   loan_status                 32571 non-null  int64
#  9   loan_percent_income         32571 non-null  float64
#  10  cb_person_default_on_file   32571 non-null  object
#  11  cb_person_cred_hist_length  32571 non-null  int64
#  12  age_range                   32556 non-null  category
#  13  income_range                32571 non-null  category
#  14  loan_amount_range           32571 non-null  category
# dtypes: category(3), float64(4), int64(4), object(4)
# memory usage: 3.3+ MB

# %%
risk_df['person_home_ownership_cat'] = risk_df.person_home_ownership.astype('category')

# %%
risk_df['person_home_ownership_cat'] = risk_df['person_home_ownership_cat'].cat.codes

# %%
risk_df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# 5              21         9900.0                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32576          57        53000.0              MORTGAGE                1.0
# 32577          54       120000.0              MORTGAGE                4.0
# 32578          65        76000.0                  RENT                3.0
# 32579          56       150000.0              MORTGAGE                5.0
# 32580          66        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# 5              VENTURE          A       2500           7.14            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# 5                     0.25                         N
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length age_range income_range loan_amount_range  \
# 1                               2     20-30        0-30k              0-5k
# 2                               3     20-30        0-30k            5k-10k
# 3                               2     20-30      50k-75k              >30k
# 4                               4     20-30      50k-75k              >30k
# 5                               2     20-30        0-30k              0-5k
# ...                           ...       ...          ...               ...
# 32576                          30     51-60      50k-75k            5k-10k
# 32577                          19     51-60    100k-150k           15k-20k
# 32578                          28     61-70     75k-100k              >30k
# 32579                          26     51-60    100k-150k           10k-15k
# 32580                          30     61-70      30k-50k            5k-10k
#
#        person_home_ownership_cat
# 1                              2
# 2                              0
# 3                              3
# 4                              3
# 5                              2
# ...                          ...
# 32576                          0
# 32577                          0
# 32578                          3
# 32579                          0
# 32580                          3
#
# [32571 rows x 16 columns]

# %%
risk_df['loan_intent_cat'] = risk_df.loan_intent.astype('category')

# %%
risk_df['loan_intent_cat'] = risk_df['loan_intent_cat'].cat.codes

# %%
risk_df['loan_intent_cat'].unique()
# Out:
# array([1, 3, 5, 4, 2, 0], dtype=int8)

# %%
risk_df['loan_intent'].unique()
# Out:
# array(['EDUCATION', 'MEDICAL', 'VENTURE', 'PERSONAL', 'HOMEIMPROVEMENT',
#        'DEBTCONSOLIDATION'], dtype=object)

# %%
risk_df['loan_grade_cat'] = risk_df.loan_grade.astype('category')

# %%
risk_df['loan_grade_cat'] = risk_df['loan_grade_cat'].cat.codes

# %%
risk_df['loan_grade_cat'].unique()
# Out:
# array([1, 2, 0, 3, 4, 5, 6], dtype=int8)

# %%
risk_df['loan_grade'].unique()
# Out:
# array(['B', 'C', 'A', 'D', 'E', 'F', 'G'], dtype=object)

# %%
risk_df['cb_person_default_on_file_cat'] = risk_df.cb_person_default_on_file.astype('category')

# %%
risk_df['cb_person_default_on_file_cat'] = risk_df['cb_person_default_on_file_cat'].cat.codes

# %%
risk_df['cb_person_default_on_file_cat'].unique()
# Out:
# array([0, 1], dtype=int8)

# %%
risk_df['cb_person_default_on_file'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
risk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32571 entries, 1 to 32580
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   person_age                     32571 non-null  int64
#  1   person_income                  32571 non-null  float64
#  2   person_home_ownership          32571 non-null  object
#  3   person_emp_length              32571 non-null  float64
#  4   loan_intent                    32571 non-null  object
#  5   loan_grade                     32571 non-null  object
#  6   loan_amnt                      32571 non-null  int64
#  7   loan_int_rate                  32571 non-null  float64
#  8   loan_status                    32571 non-null  int64
#  9   loan_percent_income            32571 non-null  float64
#  10  cb_person_default_on_file      32571 non-null  object
#  11  cb_person_cred_hist_length     32571 non-null  int64
#  12  age_range                      32556 non-null  category
#  13  income_range                   32571 non-null  category
#  14  loan_amount_range              32571 non-null  category
#  15  person_home_ownership_cat      32571 non-null  int8
#  16  loan_intent_cat                32571 non-null  int8
#  17  loan_grade_cat                 32571 non-null  int8
#  18  cb_person_default_on_file_cat  32571 non-null  int8
# dtypes: category(3), float64(4), int64(4), int8(4), object(4)
# memory usage: 3.4+ MB

# %%
risk_df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# 5              21         9900.0                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32576          57        53000.0              MORTGAGE                1.0
# 32577          54       120000.0              MORTGAGE                4.0
# 32578          65        76000.0                  RENT                3.0
# 32579          56       150000.0              MORTGAGE                5.0
# 32580          66        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# 5              VENTURE          A       2500           7.14            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# 5                     0.25                         N
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length age_range income_range loan_amount_range  \
# 1                               2     20-30        0-30k              0-5k
# 2                               3     20-30        0-30k            5k-10k
# 3                               2     20-30      50k-75k              >30k
# 4                               4     20-30      50k-75k              >30k
# 5                               2     20-30        0-30k              0-5k
# ...                           ...       ...          ...               ...
# 32576                          30     51-60      50k-75k            5k-10k
# 32577                          19     51-60    100k-150k           15k-20k
# 32578                          28     61-70     75k-100k              >30k
# 32579                          26     51-60    100k-150k           10k-15k
# 32580                          30     61-70      30k-50k            5k-10k
#
#        person_home_ownership_cat  loan_intent_cat  loan_grade_cat  \
# 1                              2                1               1
# 2                              0                3               2
# 3                              3                3               2
# 4                              3                3               2
# 5                              2                5               0
# ...                          ...              ...             ...
# 32576                          0                4               2
# 32577                          0                4               0
# 32578                          3                2               1
# 32579                          0                4               1
# 32580                          3                3               1
#
#        cb_person_default_on_file_cat
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  1
# 5                                  0
# ...                              ...
# 32576                              0
# 32577                              0
# 32578                              0
# 32579                              0
# 32580                              0
#
# [32571 rows x 19 columns]

# %%
risk_df['age_range_cat'] = risk_df.age_range.astype('category')
risk_df['age_range_cat'] = risk_df['age_range_cat'].cat.codes

# %%
risk_df['income_range_cat'] = risk_df.income_range.astype('category')
risk_df['income_range_cat'] = risk_df['income_range_cat'].cat.codes

# %%
risk_df['loan_amount_range_cat'] = risk_df.loan_amount_range.astype('category')
risk_df['loan_amount_range_cat'] = risk_df['loan_amount_range_cat'].cat.codes

# %%
risk_df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# 5              21         9900.0                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32576          57        53000.0              MORTGAGE                1.0
# 32577          54       120000.0              MORTGAGE                4.0
# 32578          65        76000.0                  RENT                3.0
# 32579          56       150000.0              MORTGAGE                5.0
# 32580          66        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# 5              VENTURE          A       2500           7.14            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income  ... age_range  income_range loan_amount_range  \
# 1                     0.10  ...     20-30         0-30k              0-5k
# 2                     0.57  ...     20-30         0-30k            5k-10k
# 3                     0.53  ...     20-30       50k-75k              >30k
# 4                     0.55  ...     20-30       50k-75k              >30k
# 5                     0.25  ...     20-30         0-30k              0-5k
# ...                    ...  ...       ...           ...               ...
# 32576                 0.11  ...     51-60       50k-75k            5k-10k
# 32577                 0.15  ...     51-60     100k-150k           15k-20k
# 32578                 0.46  ...     61-70      75k-100k              >30k
# 32579                 0.10  ...     51-60     100k-150k           10k-15k
# 32580                 0.15  ...     61-70       30k-50k            5k-10k
#
#       person_home_ownership_cat loan_intent_cat  loan_grade_cat  \
# 1                             2               1               1
# 2                             0               3               2
# 3                             3               3               2
# 4                             3               3               2
# 5                             2               5               0
# ...                         ...             ...             ...
# 32576                         0               4               2
# 32577                         0               4               0
# 32578                         3               2               1
# 32579                         0               4               1
# 32580                         3               3               1
#
#        cb_person_default_on_file_cat  age_range_cat  income_range_cat  \
# 1                                  0              0                 0
# 2                                  0              0                 0
# 3                                  0              0                 2
# 4                                  1              0                 2
# 5                                  0              0                 0
# ...                              ...            ...               ...
# 32576                              0              3                 2
# 32577                              0              3                 4
# 32578                              0              4                 3
# 32579                              0              3                 4
# 32580                              0              4                 1
#
#        loan_amount_range_cat
# 1                          0
# 2                          1
# 3                          6
# 4                          6
# 5                          0
# ...                      ...
# 32576                      1
# 32577                      3
# 32578                      6
# 32579                      2
# 32580                      1
#
# [32571 rows x 22 columns]

# %%
duplicates = risk_df.duplicated()

# %%
duplicates
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 32576    False
# 32577    False
# 32578    False
# 32579    False
# 32580    False
# Length: 32571, dtype: bool

# %%
duplicates.unique()
# Out:
# array([False,  True])

# %%
risk_df = risk_df.drop_duplicates()

# %%
dups = risk_df.duplicated()

# %%
dups.unique()
# Out:
# array([False])

# %%
risk_df.shape
# Out:
# (32406, 22)

# %%
risk_df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32406.000000   3.240600e+04       32406.000000  32406.000000
# mean      27.725421   6.589523e+04           4.760507   9592.772943
# std        6.185625   5.251945e+04           3.978768   6321.047865
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12250.000000
# max       80.000000   2.039784e+06          38.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   32406.000000  32406.000000         32406.000000
# mean       11.016800      0.218725             0.170250
# std         3.083114      0.413388             0.106786
# min         5.420000      0.000000             0.000000
# 25%         8.490000      0.000000             0.090000
# 50%        11.011695      0.000000             0.150000
# 75%        13.110000      0.000000             0.230000
# max        23.220000      1.000000             0.830000
#
#        cb_person_cred_hist_length  person_home_ownership_cat  loan_intent_cat  \
# count                32406.000000               32406.000000     32406.000000
# mean                     5.809387                   1.677097         2.533235
# std                      4.053719                   1.433170         1.730863
# min                      2.000000                   0.000000         0.000000
# 25%                      3.000000                   0.000000         1.000000
# 50%                      4.000000                   3.000000         3.000000
# 75%                      8.000000                   3.000000         4.000000
# max                     30.000000                   3.000000         5.000000
#
#        loan_grade_cat  cb_person_default_on_file_cat  age_range_cat  \
# count    32406.000000                   32406.000000   32406.000000
# mean         1.220515                       0.176788       0.250602
# std          1.167346                       0.381495       0.553338
# min          0.000000                       0.000000      -1.000000
# 25%          0.000000                       0.000000       0.000000
# 50%          1.000000                       0.000000       0.000000
# 75%          2.000000                       0.000000       0.000000
# max          6.000000                       1.000000       5.000000
#
#        income_range_cat  loan_amount_range_cat
# count      32406.000000           32406.000000
# mean           1.866012               1.286182
# std            1.289654               1.220055
# min            0.000000               0.000000
# 25%            1.000000               0.000000
# 50%            2.000000               1.000000
# 75%            3.000000               2.000000
# max            5.000000               6.000000

# %%
risk_df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 1          21         9600.0                   OWN                5.0
# 2          25         9600.0              MORTGAGE                1.0
# 3          23        65500.0                  RENT                4.0
# 4          24        54400.0                  RENT                8.0
# 5          21         9900.0                   OWN                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
# 5     VENTURE          A       2500           7.14            1
#
#    loan_percent_income  ... age_range  income_range loan_amount_range  \
# 1                 0.10  ...     20-30         0-30k              0-5k
# 2                 0.57  ...     20-30         0-30k            5k-10k
# 3                 0.53  ...     20-30       50k-75k              >30k
# 4                 0.55  ...     20-30       50k-75k              >30k
# 5                 0.25  ...     20-30         0-30k              0-5k
#
#   person_home_ownership_cat loan_intent_cat  loan_grade_cat  \
# 1                         2               1               1
# 2                         0               3               2
# 3                         3               3               2
# 4                         3               3               2
# 5                         2               5               0
#
#    cb_person_default_on_file_cat  age_range_cat  income_range_cat  \
# 1                              0              0                 0
# 2                              0              0                 0
# 3                              0              0                 2
# 4                              1              0                 2
# 5                              0              0                 0
#
#    loan_amount_range_cat
# 1                      0
# 2                      1
# 3                      6
# 4                      6
# 5                      0
#
# [5 rows x 22 columns]

# %%
risk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32406 entries, 1 to 32580
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   person_age                     32406 non-null  int64
#  1   person_income                  32406 non-null  float64
#  2   person_home_ownership          32406 non-null  object
#  3   person_emp_length              32406 non-null  float64
#  4   loan_intent                    32406 non-null  object
#  5   loan_grade                     32406 non-null  object
#  6   loan_amnt                      32406 non-null  int64
#  7   loan_int_rate                  32406 non-null  float64
#  8   loan_status                    32406 non-null  int64
#  9   loan_percent_income            32406 non-null  float64
#  10  cb_person_default_on_file      32406 non-null  object
#  11  cb_person_cred_hist_length     32406 non-null  int64
#  12  age_range                      32391 non-null  category
#  13  income_range                   32406 non-null  category
#  14  loan_amount_range              32406 non-null  category
#  15  person_home_ownership_cat      32406 non-null  int8
#  16  loan_intent_cat                32406 non-null  int8
#  17  loan_grade_cat                 32406 non-null  int8
#  18  cb_person_default_on_file_cat  32406 non-null  int8
#  19  age_range_cat                  32406 non-null  int8
#  20  income_range_cat               32406 non-null  int8
#  21  loan_amount_range_cat          32406 non-null  int8
# dtypes: category(3), float64(4), int64(4), int8(7), object(4)
# memory usage: 3.5+ MB

# %%
person_emp_length_min = risk_df['person_emp_length'].min()
person_emp_length_max = risk_df['person_emp_length'].max()

print(person_emp_length_min, person_emp_length_max)
risk_df_copy = risk_df.copy()

risk_df_copy['person_emp_length_normalized'] = (risk_df['person_emp_length'] - person_emp_length_min)/(person_emp_length_max-person_emp_length_min)
# Out:
# 0.0 38.0

# %%
risk_df = risk_df_copy

# %%
risk_df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# 5              21         9900.0                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32576          57        53000.0              MORTGAGE                1.0
# 32577          54       120000.0              MORTGAGE                4.0
# 32578          65        76000.0                  RENT                3.0
# 32579          56       150000.0              MORTGAGE                5.0
# 32580          66        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# 5              VENTURE          A       2500           7.14            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income  ... income_range  loan_amount_range  \
# 1                     0.10  ...        0-30k               0-5k
# 2                     0.57  ...        0-30k             5k-10k
# 3                     0.53  ...      50k-75k               >30k
# 4                     0.55  ...      50k-75k               >30k
# 5                     0.25  ...        0-30k               0-5k
# ...                    ...  ...          ...                ...
# 32576                 0.11  ...      50k-75k             5k-10k
# 32577                 0.15  ...    100k-150k            15k-20k
# 32578                 0.46  ...     75k-100k               >30k
# 32579                 0.10  ...    100k-150k            10k-15k
# 32580                 0.15  ...      30k-50k             5k-10k
#
#       person_home_ownership_cat loan_intent_cat loan_grade_cat  \
# 1                             2               1              1
# 2                             0               3              2
# 3                             3               3              2
# 4                             3               3              2
# 5                             2               5              0
# ...                         ...             ...            ...
# 32576                         0               4              2
# 32577                         0               4              0
# 32578                         3               2              1
# 32579                         0               4              1
# 32580                         3               3              1
#
#        cb_person_default_on_file_cat  age_range_cat  income_range_cat  \
# 1                                  0              0                 0
# 2                                  0              0                 0
# 3                                  0              0                 2
# 4                                  1              0                 2
# 5                                  0              0                 0
# ...                              ...            ...               ...
# 32576                              0              3                 2
# 32577                              0              3                 4
# 32578                              0              4                 3
# 32579                              0              3                 4
# 32580                              0              4                 1
#
#        loan_amount_range_cat  person_emp_length_normalized
# 1                          0                      0.131579
# 2                          1                      0.026316
# 3                          6                      0.105263
# 4                          6                      0.210526
# 5                          0                      0.052632
# ...                      ...                           ...
# 32576                      1                      0.026316
# 32577                      3                      0.105263
# 32578                      6                      0.078947
# 32579                      2                      0.131579
# 32580                      1                      0.052632
#
# [32406 rows x 23 columns]

# %%
loan_int_rate_min = risk_df['loan_int_rate'].min()
loan_int_rate_max = risk_df['loan_int_rate'].max()

print(loan_int_rate_min, loan_int_rate_max)
risk_df_copy = risk_df.copy()

risk_df_copy['loan_int_rate_normalized'] = (risk_df['loan_int_rate'] - loan_int_rate_min)/(loan_int_rate_max-loan_int_rate_min)
# Out:
# 5.42 23.22

# %%
risk_df = risk_df_copy

# %%
cb_person_cred_hist_length_min = risk_df['cb_person_cred_hist_length'].min()
cb_person_cred_hist_length_max = risk_df['cb_person_cred_hist_length'].max()

print(cb_person_cred_hist_length_min, cb_person_cred_hist_length_max)
risk_df_copy = risk_df.copy()

risk_df_copy['cb_person_cred_hist_length_normalized'] = (risk_df['cb_person_cred_hist_length'] - cb_person_cred_hist_length_min)/(cb_person_cred_hist_length_max-cb_person_cred_hist_length_min)
# Out:
# 2 30

# %%
risk_df = risk_df_copy

# %%
risk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32406 entries, 1 to 32580
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   person_age                             32406 non-null  int64
#  1   person_income                          32406 non-null  float64
#  2   person_home_ownership                  32406 non-null  object
#  3   person_emp_length                      32406 non-null  float64
#  4   loan_intent                            32406 non-null  object
#  5   loan_grade                             32406 non-null  object
#  6   loan_amnt                              32406 non-null  int64
#  7   loan_int_rate                          32406 non-null  float64
#  8   loan_status                            32406 non-null  int64
#  9   loan_percent_income                    32406 non-null  float64
#  10  cb_person_default_on_file              32406 non-null  object
#  11  cb_person_cred_hist_length             32406 non-null  int64
#  12  age_range                              32391 non-null  category
#  13  income_range                           32406 non-null  category
#  14  loan_amount_range                      32406 non-null  category
#  15  person_home_ownership_cat              32406 non-null  int8
#  16  loan_intent_cat                        32406 non-null  int8
#  17  loan_grade_cat                         32406 non-null  int8
#  18  cb_person_default_on_file_cat          32406 non-null  int8
#  19  age_range_cat                          32406 non-null  int8
#  20  income_range_cat                       32406 non-null  int8
#  21  loan_amount_range_cat                  32406 non-null  int8
#  22  person_emp_length_normalized           32406 non-null  float64
#  23  loan_int_rate_normalized               32406 non-null  float64
#  24  cb_person_cred_hist_length_normalized  32406 non-null  float64
# dtypes: category(3), float64(7), int64(4), int8(7), object(4)
# memory usage: 4.3+ MB

# %%
risk_df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# 5              21         9900.0                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32576          57        53000.0              MORTGAGE                1.0
# 32577          54       120000.0              MORTGAGE                4.0
# 32578          65        76000.0                  RENT                3.0
# 32579          56       150000.0              MORTGAGE                5.0
# 32580          66        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# 5              VENTURE          A       2500           7.14            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income  ... person_home_ownership_cat  loan_intent_cat  \
# 1                     0.10  ...                         2                1
# 2                     0.57  ...                         0                3
# 3                     0.53  ...                         3                3
# 4                     0.55  ...                         3                3
# 5                     0.25  ...                         2                5
# ...                    ...  ...                       ...              ...
# 32576                 0.11  ...                         0                4
# 32577                 0.15  ...                         0                4
# 32578                 0.46  ...                         3                2
# 32579                 0.10  ...                         0                4
# 32580                 0.15  ...                         3                3
#
#       loan_grade_cat cb_person_default_on_file_cat age_range_cat  \
# 1                  1                             0             0
# 2                  2                             0             0
# 3                  2                             0             0
# 4                  2                             1             0
# 5                  0                             0             0
# ...              ...                           ...           ...
# 32576              2                             0             3
# 32577              0                             0             3
# 32578              1                             0             4
# 32579              1                             0             3
# 32580              1                             0             4
#
#        income_range_cat  loan_amount_range_cat  person_emp_length_normalized  \
# 1                     0                      0                      0.131579
# 2                     0                      1                      0.026316
# 3                     2                      6                      0.105263
# 4                     2                      6                      0.210526
# 5                     0                      0                      0.052632
# ...                 ...                    ...                           ...
# 32576                 2                      1                      0.026316
# 32577                 4                      3                      0.105263
# 32578                 3                      6                      0.078947
# 32579                 4                      2                      0.131579
# 32580                 1                      1                      0.052632
#
#        loan_int_rate_normalized  cb_person_cred_hist_length_normalized
# 1                      0.321348                               0.000000
# 2                      0.418539                               0.035714
# 3                      0.551124                               0.000000
# 4                      0.497191                               0.071429
# 5                      0.096629                               0.000000
# ...                         ...                                    ...
# 32576                  0.434831                               1.000000
# 32577                  0.116292                               0.607143
# 32578                  0.312921                               0.928571
# 32579                  0.340449                               0.857143
# 32580                  0.256742                               1.000000
#
# [32406 rows x 25 columns]

# %%
risk_df.shape
# Out:
# (32406, 25)

# %%
risk_df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21         9600.0                   OWN                5.0
# 2              25         9600.0              MORTGAGE                1.0
# 3              23        65500.0                  RENT                4.0
# 4              24        54400.0                  RENT                8.0
# 5              21         9900.0                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32576          57        53000.0              MORTGAGE                1.0
# 32577          54       120000.0              MORTGAGE                4.0
# 32578          65        76000.0                  RENT                3.0
# 32579          56       150000.0              MORTGAGE                5.0
# 32580          66        42000.0                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# 5              VENTURE          A       2500           7.14            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income  ... person_home_ownership_cat  loan_intent_cat  \
# 1                     0.10  ...                         2                1
# 2                     0.57  ...                         0                3
# 3                     0.53  ...                         3                3
# 4                     0.55  ...                         3                3
# 5                     0.25  ...                         2                5
# ...                    ...  ...                       ...              ...
# 32576                 0.11  ...                         0                4
# 32577                 0.15  ...                         0                4
# 32578                 0.46  ...                         3                2
# 32579                 0.10  ...                         0                4
# 32580                 0.15  ...                         3                3
#
#       loan_grade_cat cb_person_default_on_file_cat age_range_cat  \
# 1                  1                             0             0
# 2                  2                             0             0
# 3                  2                             0             0
# 4                  2                             1             0
# 5                  0                             0             0
# ...              ...                           ...           ...
# 32576              2                             0             3
# 32577              0                             0             3
# 32578              1                             0             4
# 32579              1                             0             3
# 32580              1                             0             4
#
#        income_range_cat  loan_amount_range_cat  person_emp_length_normalized  \
# 1                     0                      0                      0.131579
# 2                     0                      1                      0.026316
# 3                     2                      6                      0.105263
# 4                     2                      6                      0.210526
# 5                     0                      0                      0.052632
# ...                 ...                    ...                           ...
# 32576                 2                      1                      0.026316
# 32577                 4                      3                      0.105263
# 32578                 3                      6                      0.078947
# 32579                 4                      2                      0.131579
# 32580                 1                      1                      0.052632
#
#        loan_int_rate_normalized  cb_person_cred_hist_length_normalized
# 1                      0.321348                               0.000000
# 2                      0.418539                               0.035714
# 3                      0.551124                               0.000000
# 4                      0.497191                               0.071429
# 5                      0.096629                               0.000000
# ...                         ...                                    ...
# 32576                  0.434831                               1.000000
# 32577                  0.116292                               0.607143
# 32578                  0.312921                               0.928571
# 32579                  0.340449                               0.857143
# 32580                  0.256742                               1.000000
#
# [32406 rows x 25 columns]

# %%
risk_df.to_csv('credit_risk_preprocessed.csv')
